# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import os
#os.chdir(r"C:\Users\hempe\Studium\Masterthesis\Repository\Masterthesis")

# %%
#load data from CSV with unicode encoding
# Import the raw data in the file raw_data.csv from data/raw
df = pd.read_csv('data/raw/BindingDB_BindingDB_Articles.tsv', sep='\t', encoding='utf-8')
# Out:
# C:\Users\hempe\AppData\Local\Temp\ipykernel_15316\3607308814.py:3: DtypeWarning: Columns (0: Ki (nM), 1: IC50 (nM), 2: Kd (nM), 3: EC50 (nM), 4: koff (s-1), 5: Temp (C), 6: Article DOI, 7: PubChem AID, 8: Authors, 9: Institution, 10: Ligand HET ID in PDB, 11: PDB ID(s) for Ligand-Target Complex, 12: ChEMBL ID of Ligand, 13: DrugBank ID of Ligand, 14: KEGG ID of Ligand, 15: ZINC ID of Ligand, 16: UniProt (SwissProt) Secondary ID(s) of Target Chain 1, 17: UniProt (TrEMBL) Submitted Name of Target Chain 1, 18: UniProt (TrEMBL) Entry Name of Target Chain 1, 19: UniProt (TrEMBL) Primary ID of Target Chain 1, 20: UniProt (TrEMBL) Secondary ID(s) of Target Chain 1, 21: BindingDB Target Chain Sequence 2, 22: PDB ID(s) of Target Chain 2, 23: UniProt (SwissProt) Recommended Name of Target Chain 2, 24: UniProt (SwissProt) Entry Name of Target Chain 2, 25: UniProt (SwissProt) Primary ID of Target Chain 2, 26: UniProt (SwissProt) Secondary ID(s) of Target Chain 2, 27: UniProt (TrEMBL) Submitted Name of Target Chain 2, 28: UniProt (TrEMBL) Entry Name of Target Chain 2, 29: UniProt (TrEMBL) Primary ID of Target Chain 2, 30: UniProt (TrEMBL) Secondary ID(s) of Target Chain 2, 31: BindingDB Target Chain Sequence 3, 32: PDB ID(s) of Target Chain 3, 33: UniProt (SwissProt) Recommended Name of Target Chain 3, 34: UniProt (SwissProt) Entry Name of Target Chain 3, 35: UniProt (SwissProt) Primary ID of Target Chain 3, 36: UniProt (SwissProt) Secondary ID(s) of Target Chain 3, 37: UniProt (TrEMBL) Submitted Name of Target Chain 3, 38: UniProt (TrEMBL) Entry Name of Target Chain 3, 39: UniProt (TrEMBL) Primary ID of Target Chain 3, 40: UniProt (TrEMBL) Secondary ID(s) of Target Chain 3, 41: BindingDB Target Chain Sequence 4, 42: PDB ID(s) of Target Chain 4, 43: UniProt (SwissProt) Recommended Name of Target Chain 4, 44: UniProt (SwissProt) Entry Name of Target Chain 4, 45: UniProt (SwissProt) Primary ID of Target Chain 4, 46: UniProt (SwissProt) Secondary ID(s) of Target Chain 4, 47: BindingDB Target Chain Sequence 5, 48: PDB ID(s) of Target Chain 5, 49: UniProt (SwissProt) Recommended Name of Target Chain 5, 50: UniProt (SwissProt) Entry Name of Target Chain 5, 51: UniProt (SwissProt) Primary ID of Target Chain 5, 52: UniProt (SwissProt) Secondary ID(s) of Target Chain 5, 53: BindingDB Target Chain Sequence 6, 54: PDB ID(s) of Target Chain 6, 55: UniProt (SwissProt) Recommended Name of Target Chain 6, 56: UniProt (SwissProt) Entry Name of Target Chain 6, 57: UniProt (SwissProt) Primary ID of Target Chain 6, 58: UniProt (SwissProt) Secondary ID(s) of Target Chain 6, 59: BindingDB Target Chain Sequence 7, 60: UniProt (SwissProt) Recommended Name of Target Chain 7, 61: UniProt (SwissProt) Entry Name of Target Chain 7, 62: UniProt (SwissProt) Primary ID of Target Chain 7, 63: UniProt (SwissProt) Secondary ID(s) of Target Chain 7, 64: BindingDB Target Chain Sequence 8, 65: PDB ID(s) of Target Chain 8, 66: UniProt (SwissProt) Recommended Name of Target Chain 8, 67: UniProt (SwissProt) Entry Name of Target Chain 8, 68: UniProt (SwissProt) Primary ID of Target Chain 8, 69: UniProt (SwissProt) Secondary ID(s) of Target Chain 8, 70: BindingDB Target Chain Sequence 9, 71: UniProt (SwissProt) Recommended Name of Target Chain 9, 72: UniProt (SwissProt) Entry Name of Target Chain 9, 73: UniProt (SwissProt) Primary ID of Target Chain 9, 74: UniProt (SwissProt) Secondary ID(s) of Target Chain 9, 75: BindingDB Target Chain Sequence 10, 76: UniProt (SwissProt) Recommended Name of Target Chain 10, 77: UniProt (SwissProt) Entry Name of Target Chain 10, 78: UniProt (SwissProt) Primary ID of Target Chain 10, 79: UniProt (SwissProt) Secondary ID(s) of Target Chain 10, 80: BindingDB Target Chain Sequence 11, 81: PDB ID(s) of Target Chain 11, 82: UniProt (SwissProt) Recommended Name of Target Chain 11, 83: UniProt (SwissProt) Entry Name of Target Chain 11, 84: UniProt (SwissProt) Primary ID of Target Chain 11, 85: UniProt (SwissProt) Secondary ID(s) of Target Chain 11) have  ...
#   df = pd.read_csv('data/raw/BindingDB_BindingDB_Articles.tsv', sep='\t', encoding='utf-8')

# %%
# For the followeing preporessing steps the data set is split into a training and test set.
# Only the training set is used for preprocessing, while the test set remains untouched until the final evaluation.
train_df, test_df = train_test_split(
    df,
    test_size=0.2,
    random_state=42
)

# Save train und test data as seperate CSV files
train_df.to_csv('data/raw/train_data.csv', index=False)
test_df.to_csv('data/raw/test_data.csv', index=False)
# Print success message
print(f'✅ New features were created and date set was splitted. Train data size: {train_df.shape}, Test data size: {test_df.shape}')
# Out:
# ✅ New features were created and date set was splitted. Train data size: (75375, 640), Test data size: (18844, 640)

# %%
train_df
# Out:
#        BindingDB Reactant_set_id  \
# 41902                      41634
# 54593                      54326
# 4301                        3840
# 62189                     126669
# 58885                      62301
# ...                          ...
# 6265                        5748
# 54886                      54619
# 76820                     367400
# 860                     50997325
# 15795                      15412
#
#                                            Ligand SMILES  \
# 41902                       O=C1N(CN2CCOCC2)c2ccccc2C1=O
# 54593  CCc1cn2CCS(=O)(=O)Oc3cc(cc1c23)C(=O)N[C@@H](Cc...
# 4301           Clc1cccc(Nc2ncnc3n[nH]c(NCc4ccccc4)c23)c1
# 62189          CC1CCCCCCCC(=O)Cc2c(Cl)c(O)cc(O)c2C(=O)O1
# 58885  COc1cc(ccc1N)-c1ccc2c(n[nH]c2c1)-c1nc2c(cccc2[...
# ...                                                  ...
# 6265   CCCN(NC(=O)[C@@H]1C[C@H](CN1C(=O)[C@@H](NC(=O)...
# 54886  CCN1CCN(CC1)c1cc2[nH]c(SC(C)(C)CCNC(=O)OC)nc2c...
# 76820  FC(F)(F)c1ccc(Cl)c(NC(=O)CN2CCN(CC2)C(=O)c2ccc...
# 860    CC(C)C1(CCc2ccc(O)cc2)CC(=O)C(Sc2cc(C)c(OS(=O)...
# 15795  Clc1cc(Cl)c2c(NCCCCCCC(=O)NCCc3c[nH]c4ccccc34)...
#
#                                             Ligand InChI  \
# 15795                                       Homo sapiens             NaN
#
#       IC50 (nM)  ... UniProt (SwissProt) Recommended Name of Target Chain 50  \
# 41902       NaN  ...                                                NaN
# 54593       450  ...                                                NaN
# 4301          7  ...                                                NaN
# 62189   1.29e+3  ...                                                NaN
# 58885      51.3  ...                                                NaN
# ...         ...  ...                                                ...
# 6265       4300  ...                                                NaN
# 54886        21  ...                                                NaN
# 76820       NaN  ...                                                NaN
# 860         3.5  ...                                                NaN
# 15795       7.8  ...                                                NaN
#
#       UniProt (SwissProt) Entry Name of Target Chain 50  \
# 41902                                               NaN
# 54593                                               NaN
# 4301                                                NaN
# 62189                                               NaN
# 58885                                               NaN
# ...                                                 ...
# 6265                                                NaN
# 54886                                               NaN
# 76820                                               NaN
# 860                                                 NaN
# 15795                                               NaN
#
#        UniProt (SwissProt) Primary ID of Target Chain 50  \
# 41902                                                NaN
# 54593                                                NaN
# 4301                                                 NaN
# 62189                                                NaN
# 58885                                                NaN
# ...                                                  ...
# 6265                                                 NaN
# 54886                                                NaN
# 76820                                                NaN
# 860                                                  NaN
# 15795                                                NaN
#
#       UniProt (SwissProt) Secondary ID(s) of Target Chain 50  \
# 41902                                                NaN
# 54593                                                NaN
# 4301                                                 NaN
# 62189                                                NaN
# 58885                                                NaN
# ...                                                  ...
# 6265                                                 NaN
# 54886                                                NaN
# 76820                                                NaN
# 860                                                  NaN
# 15795                                                NaN
#
#        UniProt (SwissProt) Alternative ID(s) of Target Chain 50  \
# 41902                                                NaN
# 54593                                                NaN
# 4301                                                 NaN
# 62189                                                NaN
# 58885                                                NaN
# ...                                                  ...
# 6265                                                 NaN
# 54886                                                NaN
# 76820                                                NaN
# 860                                                  NaN
# 15795                                                NaN
#
#       UniProt (TrEMBL) Submitted Name of Target Chain 50  \
# 41902                                                NaN
# 54593                                                NaN
# 4301                                                 NaN
# 62189                                                NaN
# 58885                                                NaN
# ...                                                  ...
# 6265                                                 NaN
# 54886                                                NaN
# 76820                                                NaN
# 860                                                  NaN
# 15795                                                NaN
#
#       UniProt (TrEMBL) Entry Name of Target Chain 50  \
# 41902                                            NaN
# 54593                                            NaN
# 4301                                             NaN
# 62189                                            NaN
# 58885                                            NaN
# ...                                              ...
# 6265                                             NaN
# 54886                                            NaN
# 76820                                            NaN
# 860                                              NaN
# 15795                                            NaN
#
#       UniProt (TrEMBL) Primary ID of Target Chain 50  \
# 41902                                            NaN
# 54593                                            NaN
# 4301                                             NaN
# 62189                                            NaN
# 58885                                            NaN
# ...                                              ...
# 6265                                             NaN
# 54886                                            NaN
# 76820                                            NaN
# 860                                              NaN
# 15795                                            NaN
#
#       UniProt (TrEMBL) Secondary ID(s) of Target Chain 50  \
# 41902                                                NaN
# 54593                                                NaN
# 4301                                                 NaN
# 62189                                                NaN
# 58885                                                NaN
# ...                                                  ...
# 6265                                                 NaN
# 54886                                                NaN
# 76820                                                NaN
# 860                                                  NaN
# 15795                                                NaN
#
#        UniProt (TrEMBL) Alternative ID(s) of Target Chain 50
# 41902                                                NaN
# 54593                                                NaN
# 4301                                                 NaN
# 62189                                                NaN
# 58885                                                NaN
# ...                                                  ...
# 6265                                                 NaN
# 54886                                                NaN
# 76820                                                NaN
# 860                                                  NaN
# 15795                                                NaN
#
# [75375 rows x 640 columns]
